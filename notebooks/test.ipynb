# %%
import  torch
mag_dist = torch.load("/root/autodl-tmp/chuandian_eq/notebooks/mag_dist.pt")
# Out:
# /root/autodl-tmp/tmp/ipykernel_8496/4220487740.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
mag_dist
# Out:
# GutenbergRichter(b: torch.Size([1000, 1]))

# %%
mag_dist.sample().shape
# Out:
# torch.Size([1000, 1])

# %%
mag_dist.b = mag_dist.b.unsqueeze(1)

# %%
mag_dist.b.shape
# Out:
# torch.Size([1000, 1, 1])

# %%
mag_dist.mag_min.shape
# Out:
# torch.Size([1000, 1])

# %%
mag_dist.batch_shape
# Out:
# torch.Size([1000, 1])

# %%
mag_dist.rsample().shape
# Out:
# torch.Size([1000, 1000, 1])

# %%
dist2 = torch.load("/root/autodl-tmp/chuandian_eq/notebooks/magnitude_dist_rtpp.pth")
# Out:
# /root/autodl-tmp/tmp/ipykernel_8496/2111045313.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
dist2.sample().shape
# Out:
# torch.Size([1000, 1])

# %%
dist2.b.shape
# Out:
# torch.Size([1000, 1])

# %%
dist2.mag_min.shape
# Out:
# torch.Size([1000, 1])

# %%
from src.distributions.gutenberg_richter import GutenbergRichter
b = torch.randn((20))
dist_mag = GutenbergRichter(b, mag_min=3.0*b.unsqueeze(1))

# %%
dist_mag.sample().shape
# Out:
# torch.Size([20, 20])

# %%
import torch
context = torch.load("/root/autodl-tmp/chuandian_eq/notebooks/context.pt")
# Out:
# /root/autodl-tmp/tmp/ipykernel_6642/2084440295.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
context
# Out:
# tensor([[[nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan]],
#
#         ...,
#
#         [[nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan]],
#
#         [[nan, nan, nan,  ..., nan, nan, nan]]], device='cuda:0')

# %%
import pandas as pd
df1_processed = pd.read_csv("/root/autodl-tmp/chuandian_eq/data/ChinaArray/raw/processed_ChinaArray.csv")

# %%
df1_processed
# Out:
#                     t  Magnitude  Latitude  Longitude  Depth        dt  \
# 0            0.538380        2.7    26.050    100.980      0  0.000000
# 1            1.455556        2.3    37.200    114.830     17  0.917176
# 2            1.572975        2.8    40.300     77.000      0  0.117419
# 3            1.853333        3.0    43.500    122.200      0  0.280359
# 4            1.870139        2.2    37.370    114.550     18  0.016806
# ...               ...        ...       ...        ...    ...       ...
# 1397553  19582.970572        2.2    37.922    115.216     12  0.002222
# 1397554  19582.977533        1.3    37.916    115.246     26  0.006961
# 1397555  19582.978881        1.2    24.327    101.880     15  0.001348
# 1397556  19582.979163        0.5    23.850    114.501      9  0.000282
# 1397557  19582.992521        2.4    29.726    106.016     13  0.013358
#
#                               ts
# 0        1970-01-01 12:55:16.000
# 1        1970-01-02 10:56:00.000
# ...
