# %% [markdown]
# Modified from "Using Deep Learning for Flexible and Scalable Earthquake Forecasting"
# Reference: [Zenodo](https://zenodo.org/records/8161777)

# %%
import sys
import pandas as pd
import numpy as np
from pathlib import Path
import torch
import src  
import matplotlib.pyplot as plt
from src.utils.utils import set_seed
import src.data.catalog as catalog
import src.catalogs as catalogs
import functools
import os
import importlib
sys.path.append(str(Path.cwd().parent))
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
set_seed(0)

# %%
checkpoint_dir = Path("../checkpoints/mixer_tpp_20260115-122948") 
# checkpoints/mixer_tpp_20250912-125450
 # "../checkpoints/mixer_tpp_20250907-112659"
 # /checkpoints/mixer_tpp_20250825-114639 /checkpoints/rtpp_20250824-214315
 # checkpoints/mixer_tpp_20250819-143535 checkpoints/mixer_tpp_20250819-143210
 # checkpoints/rtpp_20250819-142340
checkpoint_path = checkpoint_dir / "best_model_1.pth"

# %% [markdown]
# ## Loading a trained model

# %%
from src.models.builders import ModelBuilder
from src.train.config_setup import load_args_from_checkpoint,load_model_from_checkpoint

check_point = torch.load(checkpoint_path,weights_only=False)
args = load_args_from_checkpoint(None, check_point)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_builder = ModelBuilder.by_name(args.model.lower())()
model = model_builder(args, device)
model,_,_ = load_model_from_checkpoint(model, check_point)
# model.set_attn_type("flash")
# model.set_attn_dropout(0)
model = torch.compile(model)
model.eval()
# Out:
# using time scale base 1.6484907865524292 (key: tau_mean)
# tau mean: 1.6484907865524292
# load_specific_parts: None
# Checkpoint loaded: <All keys matched successfully>
# hyperparameters: {'model': 'mixer_tpp', 'num_event_types': 1, 'pad_token_id': 1, 'task_type': 'tpp', 'batch_size': 1, 'accumulation_steps': 1, 'warmup_ratio': 0.1, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'scheduler_factor': None, 'scheduler_patience': None, 'scheduler_threshold': None, 'scheduler_min_lr': 1e-06, 'scheduler_type': 'hf_cosine', 'step_lr_step_size_ratio': 0.2, 'step_lr_gamma': 0.8, 'dropout': 0.3, 'd_model': 64, 'mixer_model_config': {'input_dim': 1, 'dropout_prob': 0.1, 'd_model': 64, 'n_layer': 2, 'd_intermediate': 128, 'attn_layer_idx': [], 'ssm_cfg': {'layer': 'Mamba2Rotary', 'use_conv': False, 'rotary_emb_scale_base': 2048}, 'attn_cfg': {'layer': 'MHATime', 'num_heads': 4, 'rotary_emb_dim': 8, 'rotary_emb_scale_base': 2048, 'causal': True}, 'norm_epsilon': 1e-05, 'rms_norm': False, 'initializer_cfg': {'initializer_range': 0.02}, 'fused_add_norm': False, 'residual_in_fp32': True}, 'num_components': 32, 'dim': 1, 'epochs': 2000, 'save_dir': 'checkpoints/mixer_tpp_20260115-122948', 'cuda_id': '0', 'dataset': 'ChuanDian', 'seed': 0, 'minibatch_training': False, 'split_by_time': True, 'time_order': ['train', 'val', 'test'], 'features_input_keys': ['mag'], 'normalize_time_by_token': True, 'time_scale_base_key': 'tau_mean', 'predict_b': True, 'use_ssm_filter': False, 'B_range': [0.0001, 0.01], 'use_b_updater': False, 'use_adaptive_loss_weights': False, 'b_updater_cfg': {'delta': 0.98, 'a0': 50, 'init_b_target': 1}, 'loss_weights': {'time_weight': 1, 'mag_weight': 1, 'b_weight': 0, 'b_smooth_weight': 1e-06}, 'loss_reduction': 'per_time', 'b_range': [0.2, 2], 'cuda': True, 'tau_mean': 1.6484907865524292, 'tau_min': 2.3148149921325967e-06, 'tau_max': 32.8729133605957, 'tau_q05': 0.5829246044158936, 'tau_q025': 0.0008729455876164138, 'mag_mean': 3.5779941082000732, 'time_max': 16436.0, 'time_mean': 8854.9658203125, 'mag_completeness': 3.0, 'richter_b_mle': 0.7449380290378674, 'precision': 32, 'num_events_train': 4498, 'num_events_val': 567, 'start_epoch': 0, 'best_val_loss': inf}
# train_metrics: {'avg_time_nll': 0.355500191450119, 'avg_mag_nll': 0.3559248149394989, 'avg_total_nll': 0.7114265561103821, 'avg_b_smooth_nll': 1.5841337442398071}
# val_metrics: {'avg_time_nll': 0.8156606554985046, 'avg_mag_nll': 0.0969754308462143, 'avg_total_nll': 0.9126361608505249, 'avg_b_smooth_nll': 0.03181864321231842}
# OptimizedModule(
#   (_orig_mod): MixerTPP(
#     (base_model): MixerModelWrapper(
#       (encoder): MixerModel(
#         (input_linear): Linear(in_features=1, out_features=64, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (layers): ModuleList(
#           (0-1): 2 x Block(
#             (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             (mixer): Mamba2Rotary(
#               (in_proj): Linear(in_features=64, out_features=514, bias=False)
#               (act): SiLU()
#               (norm): RMSNorm()
#               (out_proj): Linear(in_features=128, out_features=64, bias=False)
#               (rotary_emb): RotaryEmbeddingTime()
#             )
#             (dropout): Dropout(p=0.1, inplace=False)
#             (norm2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             (mlp): GatedMLP(
#               (fc1): Linear(in_features=64, out_features=256, bias=False)
#               (fc2): Linear(in_features=128, out_features=64, bias=False)
#             )
#           )
#         )
#         (norm_f): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (hypernet_time): Linear(in_features=64, out_features=96, bias=True)
#     (hypernet_mag): Linear(in_features=64, out_features=1, bias=True)
#     (dropout): Dropout(p=0.3, inplace=False)
#   )
# )

# %% [markdown]
# ## Loading the catalog

# %%
# args.dataset = "ChinaArray" 
catalog_ds_class = catalog.Catalog.by_name(f"{args.dataset}-Standard")
catalog_ds = catalog_ds_class(root_dir=f'../data/{args.dataset}/raw',catalog_file=None)
# Out:
# Loading existing catalog from /root/autodl-tmp/chuandian_eq/data/ChuanDian/raw.

# %%
catalog_ds.full_sequence
# Out:
# Sequence(
#   inter_times: [11581],
#   arrival_times: [11580],
#   t_start: 0.0,
#   t_end: 18771.0,
#   t_nll_start: 0.0,
#   mag: [11580],
#   loc: [11580, 2],
#   depth: [11580]
# )

# %%
window_size = 300
stride = 10
arrival_times = catalog_ds.full_sequence.arrival_times
max_time = arrival_times.max().item()
window_starts = torch.arange(0, max_time - window_size + stride, stride)
counts = torch.zeros(len(window_starts), dtype=torch.int32)

for i, start in enumerate(window_starts):
    end = start + window_size
    mask = (arrival_times >= start) & (arrival_times < end)
    counts[i] = mask.sum()
plt.plot(window_starts, counts)
plt.xlabel('Window Start Time')
plt.ylabel('Event Count')
plt.title('Event Count Distribution in Sliding Windows')
plt.grid(True)
plt.show()

# %%
# b_seq = model.compute_b_value(catalog_ds.full_sequence.to(device),True)
# plt.plot(b_seq.squeeze().detach().cpu().numpy())
# plt.savefig(checkpoint_dir/'b_pred.png')
# data = b_seq.squeeze().detach().cpu().numpy()
# smooth = pd.Series(data).rolling(window=500, min_periods=1).mean()
# plt.plot(smooth)
# plt.savefig(checkpoint_dir/'b_pred_smooth.png')

# %% [markdown]
# ## Prepare the data

# %% [markdown]
# We trained the TPP model using the `train` and `val` sequences. Now we will use the unseen section of the `test` sequence (in orange) to evaluate forecasting performance of the model.

# %%
from src.utils.visualization import visualize_sequence
test_seq = catalog_ds.test[0]
train_seq = catalog_ds.train[0]
visualize_sequence(test_seq, show_nll=True)
# Out:
# <Axes: xlabel='Arrival time (days)', ylabel='Magnitude'>

# %% [markdown]
# We would like to generate a 30-day forecast for the interval `[13000, 13030]`. For this, we select two subsequences:
# - `past_seq`: Contains events from `[0, 13000]`, is used to condition the model
# - `observed_seq`: Contains actually observed events from `[13000, 13030]`.

# %%
t_forecast = 18000 # 4000 13000
duration = 30 # 7 30
num_samples = 10000 # 10000

# Past events that we condition on
past_seq = test_seq.get_subsequence(0, t_forecast) #  3500
observed_seq = test_seq.get_subsequence(t_forecast, t_forecast + duration)

# %% [markdown]
# ## Generate the forecast

# %%
past_seq.float()
# Out:
# Sequence(
#   inter_times: [10837],
#   arrival_times: [10836],
#   t_start: 0.0,
#   t_end: 18000.0,
#   t_nll_start: 17532.0,
#   mag: [10836],
#   loc: [10836, 2],
#   depth: [10836]
# )

# %%
past_batch = src.data.Batch.from_list([past_seq])

# %%
torch.mean(past_batch.inter_times)
# Out:
# tensor(1.6610)

# %%
if torch.cuda.is_available():
    model.to('cuda:0')
    past_seq.to('cuda:0')

# %%
# torch.backends.cudnn.enabled = False

# %%
set_seed(3) 
model.eval()  # Set the model to evaluation mode

all_forecasts = []
samples_per_batch = 10000
for _ in range(num_samples // samples_per_batch):
    # forecast = model.sample_with_cache(batch_size=samples_per_batch, duration=duration, past_seq=past_seq, return_sequences=True)
    forecast = model.sample(batch_size=samples_per_batch, duration=duration, past_seq=past_seq, return_sequences=True, max_sample_len=4000)
    all_forecasts.extend(forecast)
# Out:
# /root/autodl-tmp/chuandian_eq/src/data/sequence.py:246: UserWarning: Found 1 zero inter-event times in the sequence. This violates fundamental assumptions of TPP models and may lead to incorrect log-likelihood values.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 8
#       5 samples_per_batch = 10000
#       6 for _ in range(num_samples // samples_per_batch):
#       7     # forecast = model.sample_with_cache(batch_size=samples_per_batch, duration=duration, past_seq=past_seq, return_sequences=True)
# ----> 8     forecast = model.sample(batch_size=samples_per_batch, duration=duration, past_seq=past_seq, return_sequences=True, max_sample_len=4000)
#       9     all_forecasts.extend(forecast)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/autodl-tmp/chuandian_eq/src/models/tpp/mixer_tpp.py:355, in MixerTPP.sample(self, batch_size, duration, t_start, past_seq, return_sequences, predict_b, max_sample_len)
#     353 t_start = past_seq.t_end
#     354 buffer_batch = src.data.Batch.init_sample_batch(past_seq=past_seq.init_sample_sequence(), batch_size=batch_size, max_sample_len=max_sample_len)
# --> 355 current_state = self.get_current_state(src.data.Batch.from_list([past_seq])[:,:-1],inference_params=inference_params)
#     356 # buffer_batch = src.data.Batch.init_sample_batch(past_seq=past_seq, batch_size=batch_size, max_sample_len=max_sample_len)
#     357 # current_state = self.get_current_state(buffer_batch.get_sample_batch(), inference_params=inference_params)  # (1, 1, C)
#     358 current_state = current_state.expand(batch_size, -1, -1)  # (B, 1, C)
#
# File ~/autodl-tmp/chuandian_eq/src/models/tpp/mixer_tpp.py:148, in MixerTPP.get_current_state(self, batch, inference_params)
#     143 def get_current_state(self,
#     144         batch: src.data.Batch,
#     145         inference_params: Optional[InferenceParams] = None,
#     146         ):
#     147     """Get the current state of the model for inference."""
# --> 148     current_state = self.base_model(batch, inference_params=inference_params)
#     149     if inference_params is not None:
#     150         inference_params.seqlen_offset += 1
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/autodl-tmp/chuandian_eq/src/models/mamba/mixer_seq.py:306, in MixerModelWrapper.forward(self, batch, inference_params)
#     303 batch = batch.to(self.device)
#     305 inputs = self.input_adapter(batch)
# --> 306 out = self.encoder(**inputs, inference_params=inference_params)
#     307 if "non_pad_mask" in inputs:
#     308     non_pad_mask = inputs["non_pad_mask"]
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/autodl-tmp/chuandian_eq/src/models/mamba/mixer_seq.py:211, in MixerModel.forward(self, features, inference_params, **mixer_kwargs)
#     209 residual = None
#     210 for layer in self.layers:
# --> 211     hidden_states, residual = layer(
#     212         hidden_states, residual, inference_params=inference_params, **mixer_kwargs
#     213     )
#     214 if not self.fused_add_norm:
#     215     residual = (hidden_states + residual) if residual is not None else hidden_states
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/autodl-tmp/chuandian_eq/src/models/mamba/block.py:74, in Block.forward(self, hidden_states, residual, inference_params, **mixer_kwargs)
#      69 sig = inspect.signature(self.mixer.forward)
#      70 accepted_kwargs = {
#      71     k: v for k, v in mixer_kwargs.items()
#      72     if k in sig.parameters
#      73 }
# ---> 74 hidden_states = self.mixer(hidden_states, inference_params=inference_params, **accepted_kwargs)
#      75 hidden_states = self.dropout(hidden_states)
#      77 if self.mlp is not None:
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/autodl-tmp/chuandian_eq/src/models/mamba/mamba2_rotary.py:260, in Mamba2Rotary.forward(self, u, times, seqlen, seq_idx, cu_seqlens, inference_params)
#     256 if self.rotary_emb_dim > 0:
#     257     B, C = self.rotary_emb(
#     258         B, C, times=times, seqlen_offset=seqlen_offset, max_seqlen=rotary_max_seqlen
#     259     )
# --> 260 y = mamba_chunk_scan_combined(
#     261     rearrange(x, "b l (h p) -> b l h p", p=self.headdim),
#     262     dt,
#     263     A,
#     264     B,
#     265     C,
#     266     chunk_size=self.chunk_size,
#     267     D=rearrange(self.D, "(h p) -> h p", p=self.headdim) if self.D_has_hdim else self.D,
#     268     z=rearrange(z, "b l (h p) -> b l h p", p=self.headdim) if not self.rmsnorm else None,
#     269     dt_bias=self.dt_bias,
#     270     dt_softplus=True,
#     271     seq_idx=seq_idx,
#     272     cu_seqlens=cu_seqlens,
#     273     **dt_limit_kwargs,
#     274     return_final_states=ssm_state is not None,
#     275     return_varlen_states=cu_seqlens is not None and inference_params is not None,
#     276 )
#     277 if ssm_state is not None:
#     278     y, last_state, *rest = y
#
# File ~/miniconda3/lib/python3.12/site-packages/mamba_ssm/ops/triton/ssd_combined.py:594, in mamba_chunk_scan_combined(x, dt, A, B, C, chunk_size, D, z, dt_bias, initial_states, seq_idx, cu_seqlens, dt_softplus, dt_limit, return_final_states, return_varlen_states)
#     575 def mamba_chunk_scan_combined(x, dt, A, B, C, chunk_size, D=None, z=None, dt_bias=None, initial_states=None, seq_idx=None, cu_seqlens=None, dt_softplus=False, dt_limit=(0.0, float("inf")), return_final_states=False, return_varlen_states=False):
#     576     """
#     577     Argument:
#     578         x: (batch, seqlen, nheads, headdim)
#    (...)
#     592         out: (batch, seqlen, nheads, headdim)
#     593     """
# --> 594     return MambaChunkScanCombinedFn.apply(x, dt, A, B, C, chunk_size, D, z, dt_bias, initial_states, seq_idx, cu_seqlens, dt_softplus, dt_limit, return_final_states, return_varlen_states)
#
# File ~/miniconda3/lib/python3.12/site-packages/torch/autograd/function.py:575, in Function.apply(cls, *args, **kwargs)
#     572 if not torch._C._are_functorch_transforms_active():
#     573     # See NOTE: [functorch vjp and autograd interaction]
#     574     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 575     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     577 if not is_setup_ctx_defined:
#     578     raise RuntimeError(
#     579         "In order to use an autograd.Function with functorch transforms "
#     580         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     581         "staticmethod. For more details, please see "
#     582         "https://pytorch.org/docs/main/notes/extending.func.html"
#     583     )
#
# File ~/miniconda3/lib/python3.12/site-packages/mamba_ssm/ops/triton/ssd_combined.py:553, in MambaChunkScanCombinedFn.forward(ctx, x, dt, A, B, C, chunk_size, D, z, dt_bias, initial_states, seq_idx, cu_seqlens, dt_softplus, dt_limit, return_final_states, return_varlen_states)
#     551 else:
#     552     assert cu_seqlens is not None, "cu_seqlens must be provided if return_varlen_states is True"
# --> 553 out, out_x, dt_out, dA_cumsum, states, final_states, *rest = _mamba_chunk_scan_combined_fwd(x, dt, A, B, C, chunk_size, D=D, z=z, dt_bias=dt_bias, initial_states=initial_states, seq_idx=seq_idx, cu_seqlens=cu_seqlens, dt_softplus=dt_softplus, dt_limit=dt_limit)
#     554 ctx.save_for_backward(out if z is None else out_x, x, dt, dA_cumsum, A, B, C, D, z, dt_bias, initial_states, seq_idx)
#     555 ctx.dt_softplus = dt_softplus
#
# File ~/miniconda3/lib/python3.12/site-packages/mamba_ssm/ops/triton/ssd_combined.py:336, in _mamba_chunk_scan_combined_fwd(x, dt, A, B, C, chunk_size, D, z, dt_bias, initial_states, seq_idx, cu_seqlens, dt_softplus, dt_limit)
#     333 states, final_states = [rearrange(t, "... (p n) -> ... p n", n=dstate) for t in [states, final_states]]
#     334 # states_tmp0 = rearrange(_state_passing_fwd(rearrange(states_tmp0, "... p n -> ... (p n)"), dA_cumsum_tmp0[:, :, :, -1], chunk_size=chunk_size), "... (p n) -> ... p n", n=dstate)
#     335 # states_tmp1 = rearrange(_state_passing_fwd(rearrange(states_tmp1, "... p n -> ... (p n)"), dA_cumsum_tmp1[:, :, :, -1], chunk_size=chunk_size), "... (p n) -> ... p n", n=dstate)
# --> 336 CB = _bmm_chunk_fwd(C, B, chunk_size, seq_idx=seq_idx, output_dtype=torch.float32)
#     337 out, out_x = _chunk_scan_fwd(CB, x, dt, dA_cumsum, C, states, D=D, z=z, seq_idx=seq_idx)
#     338 if cu_seqlens is None:
#
# File ~/miniconda3/lib/python3.12/site-packages/mamba_ssm/ops/triton/ssd_bmm.py:197, in _bmm_chunk_fwd(a, b, chunk_size, seq_idx, causal, output_dtype)
#     194 grid = lambda META: (triton.cdiv(chunk_size, META['BLOCK_SIZE_M']) * triton.cdiv(chunk_size, META['BLOCK_SIZE_N']),
#     195                 batch, nchunks if not has_groups else nchunks * ngroups)
#     196 with torch.cuda.device(a.device.index):
# --> 197     _bmm_chunk_fwd_kernel[grid](
#     198         a, b, out, seq_idx,
#     199         seqlen, chunk_size, k, ngroups if has_groups else 1,
#     200         a.stride(0), a.stride(1), 0 if not has_groups else a.stride(2), a.stride(-1),
#     201         b.stride(0), b.stride(1), 0 if not has_groups else b.stride(2), b.stride(-1),
#     202         out.stride(0), out.stride(1), 0 if not has_groups else out.stride(2), out.stride(-2), out.stride(-1),
#     203         *((seq_idx.stride(0), seq_idx.stride(1)) if seq_idx is not None else (0, 0)),
#     204         causal,
#     205         dot_dtype,
#     206         HAS_SEQ_IDX=seq_idx is not None,
#     207     )
#     208 return out
#
# File ~/miniconda3/lib/python3.12/site-packages/triton/runtime/jit.py:345, in KernelInterface.__getitem__.<locals>.<lambda>(*args, **kwargs)
#     339 def __getitem__(self, grid) -> T:
#     340     """
#     341     A JIT function is launched with: fn[grid](*args, **kwargs).
#     342     Hence JITFunction.__getitem__ returns a callable proxy that
#     343     memorizes the grid.
#     344     """
# --> 345     return lambda *args, **kwargs: self.run(grid=grid, warmup=False, *args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/triton/runtime/autotuner.py:156, in Autotuner.run(self, *args, **kwargs)
#     154 pruned_configs = self.prune_configs(kwargs)
#     155 bench_start = time.time()
# --> 156 timings = {config: self._bench(*args, config=config, **kwargs) for config in pruned_configs}
#     157 bench_end = time.time()
#     158 self.bench_time = bench_end - bench_start
#
# File ~/miniconda3/lib/python3.12/site-packages/triton/runtime/autotuner.py:133, in Autotuner._bench(self, config, *args, **meta)
#     131             bench_res = do_bench_cudagraph(kernel_call, rep=self.num_reps, return_mode="median")
#     132         return bench_res
# --> 133     return do_bench(kernel_call, warmup=self.num_warmups, rep=self.num_reps, quantiles=(0.5, 0.2, 0.8))
#     134 except (OutOfResources, CompileTimeAssertionFailure):
#     135     return float("inf") if self.use_cuda_graph else [float("inf"), float("inf"), float("inf")]
#
# File ~/miniconda3/lib/python3.12/site-packages/triton/testing.py:145, in do_bench(fn, warmup, rep, grad_to_none, quantiles, fast_flush, return_mode, device_type)
#     143         x.grad = None
#     144 # we clear the L2 cache before each run
# --> 145 cache.zero_()
#     146 # record time of `fn`
#     147 start_event[i].record()
#
# KeyboardInterrupt:

# %% [markdown]
# `forecast` is a list, where each element is a `eq.data.Sequence` that represents a possible continuation of the catalog over the interval `[13000, 13030]`.
#
# With the following function, we
# - visualize 10 randomly chosen trajectories as a counting process
# - plot the distribution of the total # of events in the forecast interval

# %%
# importlib.reload(src.utils.visualization)

# %%
date_str = catalog_ds.metadata['start_ts'].strftime('%Y-%m-%d')
src.utils.visualization.visualize_trajectories(test_seq, all_forecasts,save_path=checkpoint_dir/"all_forecasts.pdf",figsize=(10,3),xlabel='Days since '+date_str)
# src.utils.visualization.visualize_trajectories(train_seq, all_forecasts,save_path=checkpoint_dir/"all_forecasts.png")

# %%
import  src.utils.catalog_tests as catalog_tests

# %% [markdown]
# N-test

# %%
number_test_result = catalog_tests.run_number_test_result(
    event_counts=[len(fc) for fc in all_forecasts],
    obs_count=len(observed_seq),                   
    min_mw=catalog_ds.metadata['mag_completeness'],
    obs_name='observed',
    sim_name='Simulated',
    plot=False
)
ax= number_test_result.plot(plot_args={'figsize':(6.4,4.8),'tight_layout':False})
plt.savefig(checkpoint_dir/'n_test.pdf')

# %% [markdown]
# M-test

# %%
config_dict = {
    'min_mw': catalog_ds.metadata['mag_completeness'],
    'max_mw': 10,
    'dmw': 0.01
}

magnitude_bins, distribution = catalog_tests.compute_magnitude_distribution(
    forecast[0].mag.cpu().numpy(), 
   **config_dict
)

# %%
get_counts = functools.partial(catalog_tests.compute_magnitude_distribution, **config_dict)
result_dict = catalog_tests.magnitude_test_from_counts(
    observed_catalog=observed_seq,
    forecast_catalogs=all_forecasts,
    get_counts=lambda cat: get_counts(np.asarray(cat.mag.cpu())),
    verbose=False
)
# Out:
# [DEBUG] observed_catalog = Sequence(
#   inter_times: [9],
#   arrival_times: [8],
#   t_start: 18000.0,
#   t_end: 18030.001,
#   t_nll_start: 18000.0,
#   mag: [8],
#   loc: [8, 2],
#   depth: [8]
# )
# [DEBUG] obs_hist stats: {'shape': (2, 701), 'sum': 4564.5, 'min': 0.0, 'max': 10.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 696}
# [DEBUG] obs_hist head(8) = [3.   3.01 3.02 3.03 3.04 3.05 3.06 3.07]
#
# [DEBUG] forecast[0] = Sequence(
#   inter_times: [32],
#   arrival_times: [31],
#   t_start: 18000.0,
#   t_end: 18030.0,
#   t_nll_start: 18000.0,
#   mag: [31]
# )
# [DEBUG] forecast[0].counts stats: {'shape': (2, 701), 'sum': 4587.5, 'min': 0.0, 'max': 10.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 672}
# [DEBUG] forecast[0].counts head(8) = [3.   3.01 3.02 3.03 3.04 3.05 3.06 3.07]
#
# [DEBUG] forecast[1] = Sequence(
#   inter_times: [20],
#   arrival_times: [19],
#   t_start: 18000.0,
#   t_end: 18030.0,
#   t_nll_start: 18000.0,
#   mag: [19]
# )
# [DEBUG] forecast[1].counts stats: {'shape': (2, 701), 'sum': 4575.5, 'min': 0.0, 'max': 10.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 683}
# [DEBUG] forecast[1].counts head(8) = [3.   3.01 3.02 3.03 3.04 3.05 3.06 3.07]
#
# [DEBUG] forecast[2] = Sequence(
#   inter_times: [32],
#   arrival_times: [31],
#   t_start: 18000.0,
#   t_end: 18030.0,
#   t_nll_start: 18000.0,
#   mag: [31]
# )
# [DEBUG] forecast[2].counts stats: {'shape': (2, 701), 'sum': 4587.5, 'min': 0.0, 'max': 10.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 673}
# [DEBUG] forecast[2].counts head(8) = [3.   3.01 3.02 3.03 3.04 3.05 3.06 3.07]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 458591.0, 'min': 0.0, 'max': 1000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 409}
# [DEBUG] sum_hist (running) head(8) = [300. 301. 302. 303. 304. 305. 306. 307.]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 915992.0, 'min': 0.0, 'max': 2000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 396}
# [DEBUG] sum_hist (running) head(8) = [600. 602. 604. 606. 608. 610. 612. 614.]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 1373294.0, 'min': 0.0, 'max': 3000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 390}
# [DEBUG] sum_hist (running) head(8) = [900. 903. 906. 909. 912. 915. 918. 921.]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 1832027.0, 'min': 0.0, 'max': 4000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 324}
# [DEBUG] sum_hist (running) head(8) = [1200. 1204. 1208. 1212. 1216. 1220. 1224. 1228.]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 2290408.0, 'min': 0.0, 'max': 5000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 293}
# [DEBUG] sum_hist (running) head(8) = [1500. 1505. 1510. 1515. 1520. 1525. 1530. 1535.]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 2749432.0, 'min': 0.0, 'max': 6000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 254}
# [DEBUG] sum_hist (running) head(8) = [1800. 1806. 1812. 1818. 1824. 1830. 1836. 1842.]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 3207981.0, 'min': 0.0, 'max': 7000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 243}
# [DEBUG] sum_hist (running) head(8) = [2100. 2107. 2114. 2121. 2128. 2135. 2142. 2149.]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 3665949.0, 'min': 0.0, 'max': 8000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 238}
# [DEBUG] sum_hist (running) head(8) = [2400. 2408. 2416. 2424. 2432. 2440. 2448. 2456.]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum':
.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 68}
# [DEBUG] sum_hist (running) head(8) = [24600. 24682. 24764. 24846. 24928. 25010. 25092. 25174.]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 38023418.00000001, 'min': 0.0, 'max': 83000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 68}
# [DEBUG] sum_hist (running) head(8) = [24900. 24983. 25066. 25149. 25232. 25315. 25398. 25481.]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 38480836.00000001, 'min': 0.0, 'max': 84000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 68}
# [DEBUG] sum_hist (running) head(8) = [25200. 25284. 25368. 25452. 25536. 25620. 25704. 25788.]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 38938416.00000001, 'min': 0.0, 'max': 85000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 68}
# [DEBUG] sum_hist (running) head(8) = [25500. 25585. 25670. 25755. 25840. 25925. 26010. 26095.]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 39396295.00000001, 'min': 0.0, 'max': 86000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 68}
# [DEBUG] sum_hist (running) head(8) = [25800.         25886.         25972.         26058.
#  26144.00000001 26230.         26316.         26402.        ]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 39855201.00000001, 'min': 0.0, 'max': 87000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 67}
# [DEBUG] sum_hist (running) head(8) = [26100.         26187.         26274.         26361.
#  26448.00000001 26535.         26622.         26709.        ]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 40313285.00000001, 'min': 0.0, 'max': 88000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 67}
# [DEBUG] sum_hist (running) head(8) = [26400.         26488.         26576.         26664.
#  26752.00000001 26840.         26928.         27016.        ]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 40771953.00000001, 'min': 0.0, 'max': 89000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 65}
# [DEBUG] sum_hist (running) head(8) = [26700.         26789.         26878.         26967.
#  27056.00000001 27145.         27234.         27323.        ]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 41229503.000000015, 'min': 0.0, 'max': 90000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 65}
# [DEBUG] sum_hist (running) head(8) = [27000.         27090.         27180.         27270.
#  27360.00000001 27450.         27540.         27630.        ]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 41687395.000000015, 'min': 0.0, 'max': 91000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 63}
# [DEBUG] sum_hist (running) head(8) = [27300.         27391.         27482.         27573.
#  27664.00000001 27755.         27846.         27937.        ]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 42145560.000000015, 'min': 0.0, 'max': 92000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 63}
# [DEBUG] sum_hist (running) head(8) = [27600.         27692.         27784.         27876.
#  27968.00000001 28060.         28152.         28244.        ]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 42603469.000000015, 'min': 0.0, 'max': 93000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 63}
# [DEBUG] sum_hist (running) head(8) = [27900.         27992.99999999 28086.         28179.
#  28272.00000001 28365.         28458.         28551.        ]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 43061008.000000015, 'min': 0.0, 'max': 94000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 63}
# [DEBUG] sum_hist (running) head(8) = [28200.         28293.99999999 28388.         28482.
#  28576.00000001 28670.         28764.         28858.        ]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 43519858.00000001, 'min': 0.0, 'max': 95000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 62}
# [DEBUG] sum_hist (running) head(8) = [28500.         28594.99999999 28690.         28785.
#  28880.00000001 28975.         29070.         29165.        ]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 43977690.00000001, 'min': 0.0, 'max': 96000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 62}
# [DEBUG] sum_hist (running) head(8) = [28800.         28895.99999999 28992.         29088.
#  29184.00000001 29280.         29376.         29472.        ]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 44435531.00000001, 'min': 0.0, 'max': 97000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 62}
# [DEBUG] sum_hist (running) head(8) = [29100.         29196.99999999 29294.         29391.
#  29488.00000001 29585.         29682.         29779.        ]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 44894017.00000001, 'min': 0.0, 'max': 98000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 61}
# [DEBUG] sum_hist (running) head(8) = [29400.         29497.99999999 29596.         29694.
#  29792.00000001 29890.         29988.         30086.        ]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 45352026.000000015, 'min': 0.0, 'max': 99000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 59}
# [DEBUG] sum_hist (running) head(8) = [29700.         29798.99999999 29898.         29997.
#  30096.00000001 30195.         30294.00000001 30393.        ]
# [DEBUG] sum_hist (running) stats: {'shape': (2, 701), 'sum': 45810113.000000015, 'min': 0.0, 'max': 100000.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 58}
# [DEBUG] sum_hist (running) head(8) = [30000.         30099.99999999 30200.         30300.
#  30400.00000001 30500.         30600.00000001 30700.        ]
#
# [DEBUG] After first pass:
# [DEBUG] union_hist (mean forecast) stats: {'shape': (2, 701), 'sum': 4581.011300000001, 'min': 0.0, 'max': 10.0, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 58}
# [DEBUG] union_hist (mean forecast) head(8) = [3.   3.01 3.02 3.03 3.04 3.05 3.06 3.07]
#
# [DEBUG] scale_union = n_obs/n_union = 4564.5/4581.011300000001 = 0.9963957085196448
# [DEBUG] scaled_union_hist stats: {'shape': (2, 701), 'sum': 4564.5, 'min': 0.0, 'max': 9.963957085196448, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 58}
# [DEBUG] scaled_union_hist head(8) = [2.98918713 2.99915108 3.00911504 3.019079   3.02904295 3.03900691
#  3.04897087 3.05893483]
#
# [DEBUG] Second pass forecast[0] = Sequence(
#   inter_times: [32],
#   arrival_times: [31],
#   t_start: 18000.0,
#   t_end: 18030.0,
#   t_nll_start: 18000.0,
#   mag: [31]
# )
# [DEBUG] n_events=4587.5, scale=0.9949863760217984
# [DEBUG] catalog_hist[0] stats: {'shape': (2, 701), 'sum': 4564.5, 'min': 0.0, 'max': 9.949863760217983, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 672}
# [DEBUG] catalog_hist[0] head(8) = [2.98495913 2.99490899 3.00485886 3.01480872 3.02475858 3.03470845
#  3.04465831 3.05460817]
# [DEBUG] logA[0] = _safe_log10(catalog_hist+1) stats: {'shape': (2, 701), 'sum': 609.2646723367295, 'min': 0.0, 'max': 1.0394087156552574, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 672}
# [DEBUG] logA[0] = _safe_log10(catalog_hist+1) head(8) = [0.60042387 0.60150689 0.60258721 0.60366486 0.60473984 0.60581216
#  0.60688184 0.60794889]
# [DEBUG] logB = _safe_log10(scaled_union_hist+1) stats: {'shape': (2, 701), 'sum': 610.2273806298371, 'min': 0.0, 'max': 1.039967326967894, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 58}
# [DEBUG] logB = _safe_log10(scaled_union_hist+1) head(8) = [0.60088441 0.60196781 0.60304852 0.60412654 0.6052019  0.6062746
#  0.60734465 0.60841208]
#
# [DEBUG] Second pass forecast[1] = Sequence(
#   inter_times: [20],
#   arrival_times: [19],
#   t_start: 18000.0,
#   t_end: 18030.0,
#   t_nll_start: 18000.0,
#   mag: [19]
# )
# [DEBUG] n_events=4575.5, scale=0.9975958911594361
# [DEBUG] catalog_hist[1] stats: {'shape': (2, 701), 'sum': 4564.500000000001, 'min': 0.0, 'max': 9.975958911594361, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 683}
# [DEBUG] catalog_hist[1] head(8) = [2.99278767 3.00276363 3.01273959 3.02271555 3.03269151 3.04266747
#  3.05264343 3.06261939]
# [DEBUG] logA[1] = _safe_log10(catalog_hist+1) stats: {'shape': (2, 701), 'sum': 606.4817871210097, 'min': 0.0, 'max': 1.0404424725881467, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 683}
# [DEBUG] logA[1] = _safe_log10(catalog_hist+1) head(8) = [0.60127622 0.60235995 0.60344098 0.60451932 0.605595   0.60666802
#  0.60773839 0.60880614]
# [DEBUG] logB = _safe_log10(scaled_union_hist+1) stats: {'shape': (2, 701), 'sum': 610.2273806298371, 'min': 0.0, 'max': 1.039967326967894, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 58}
# [DEBUG] logB = _safe_log10(scaled_union_hist+1) head(8) = [0.60088441 0.60196781 0.60304852 0.60412654 0.6052019  0.6062746
#  0.60734465 0.60841208]
#
# [DEBUG] Second pass forecast[2] = Sequence(
#   inter_times: [32],
#   arrival_times: [31],
#   t_start: 18000.0,
#   t_end: 18030.0,
#   t_nll_start: 18000.0,
#   mag: [31]
# )
# [DEBUG] n_events=4587.5, scale=0.9949863760217984
# [DEBUG] catalog_hist[2] stats: {'shape': (2, 701), 'sum': 4564.5, 'min': 0.0, 'max': 9.949863760217983, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 673}
# [DEBUG] catalog_hist[2] head(8) = [2.98495913 2.99490899 3.00485886 3.01480872 3.02475858 3.03470845
#  3.04465831 3.05460817]
# [DEBUG] logA[2] = _safe_log10(catalog_hist+1) stats: {'shape': (2, 701), 'sum': 609.1404596989202, 'min': 0.0, 'max': 1.0394087156552574, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 673}
# [DEBUG] logA[2] = _safe_log10(catalog_hist+1) head(8) = [0.60042387 0.60150689 0.60258721 0.60366486 0.60473984 0.60581216
#  0.60688184 0.60794889]
# [DEBUG] logB = _safe_log10(scaled_union_hist+1) stats: {'shape': (2, 701), 'sum': 610.2273806298371, 'min': 0.0, 'max': 1.039967326967894, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 58}
# [DEBUG] logB = _safe_log10(scaled_union_hist+1) head(8) = [0.60088441 0.60196781 0.60304852 0.60412654 0.6052019  0.6062746
#  0.60734465 0.60841208]
#
# [DEBUG] Observed statistic inputs:
# [DEBUG] logObs = _safe_log10(obs_hist+1) stats: {'shape': (2, 701), 'sum': 603.505759804967, 'min': 0.0, 'max': 1.0413926851582251, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 696}
# [DEBUG] logObs = _safe_log10(obs_hist+1) head(8) = [0.60205999 0.60314437 0.60422605 0.60530505 0.60638137 0.60745502
#  0.60852603 0.60959441]
# [DEBUG] logUnion = _safe_log10(scaled_union_hist+1) stats: {'shape': (2, 701), 'sum': 610.2273806298371, 'min': 0.0, 'max': 1.039967326967894, 'finite_ratio': 1.0, 'nan_count': 0, 'inf_count': 0, 'neg_count': 0, 'zero_count': 58}
# [DEBUG] logUnion = _safe_log10(scaled_union_hist+1) head(8) = [0.60088441 0.60196781 0.60304852 0.60412654 0.6052019  0.6062746
#  0.60734465 0.60841208]
# [DEBUG] obs_d_stat = 1.279123109224274
# [DEBUG] test_distribution size = 10000
# [DEBUG] test_distribution nan_count = 0
# [DEBUG] test_distribution inf_count = 0
# [DEBUG] test_distribution min/max = 0.7781550103387959 42.76929397194842

# %%
magnitude_test_result = catalog_tests.run_magnitude_test_result(
    result_dict=result_dict,
    obs_catalog_repr='obs',
   obs_name='observed',
    sim_name='Simulated',
    plot=False
)
magnitude_test_result.plot(plot_args={'figsize':(6.4,4.8),'tight_layout':False})
plt.savefig(checkpoint_dir/'m_test.pdf')

# %%
checkpoint_dir
# Out:
# PosixPath('../checkpoints/mixer_tpp_20260114-213956')
